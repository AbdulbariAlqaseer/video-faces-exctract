# %%
from config import SAVE_DF_PATH, MODEL_MEDIAPIPE_PATH, SAVE_IMAGE_PATH, VIDEO_PATH
from Face_detection_time_tracker import FaceDetectionTimeTracker

# %%
algo = FaceDetectionTimeTracker(VIDEO_PATH, model="mediapipe", memorize_face_sec=15)
# Out:
# self.fps = 23.976023976023978

# %%
res = algo.run()

# %%
res
# Out:
#    start_index_frame  end_index_frame  duration_existance  \
# 0               69.0            138.0                   2
# 1              115.0            161.0                   1
# 2             1771.0           1771.0                   0
# 3             2185.0           2185.0                   0
# 4              874.0           2415.0                  26
# 5             1012.0           2576.0                  39
#
#                          unique_name  \
# 0     ID0-fromFrame69.0_toFrame138.0
# 1    ID1-fromFrame115.0_toFrame161.0
# 2  ID4-fromFrame1771.0_toFrame1771.0
# 3  ID5-fromFrame2185.0_toFrame2185.0
# 4   ID2-fromFrame874.0_toFrame2415.0
# 5  ID3-fromFrame1012.0_toFrame2576.0
#
#                                      best_face_image  start_time    end_time
# 0  [[[115, 115, 113], [116, 116, 114], [117, 117,...    2.877875    5.755750
# 1  [[[21, 18, 17], [20, 17, 16], [19, 16, 17], [1...    4.796458    6.715042
# 2  [[[26, 26, 33], [26, 26, 33], [26, 26, 33], [2...   73.865458   73.865458
# 3  [[[55, 60, 78], [47, 52, 70], [47, 52, 70], [5...   91.132708   91.132708
# 4  [[[22, 24, 26], [27, 29, 31], [26, 28, 30], [2...   36.453083  100.725625
# 5  [[[38, 43, 49], [39, 44, 50], [33, 38, 44], [2...   42.208833  107.440667

# %%
import cv2
import matplotlib.pyplot as plt

# %%
plt.imshow(res.iloc[5].best_face_image[:,:,::-1])
